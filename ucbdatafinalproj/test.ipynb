# %%
import os

import pandas as pd
import numpy as np
import sqlite3
import pandas 

import requests

from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

from flask import Flask, jsonify, render_template,request
from flask_sqlalchemy import SQLAlchemy

import seaborn as sns

# Import SQLAlchemy `automap` and other dependencies here
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

app = Flask(__name__)

# %%
engine = create_engine("sqlite:///crimenew.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
app.config["SQLALCHEMY_DATABASE_URI"] = "sqlite:///crimenew.sqlite"
db = SQLAlchemy(app)
# Out:
# /anaconda3/lib/python3.7/site-packages/flask_sqlalchemy/__init__.py:835: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   'SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and '

# %%
crime = Base.classes.crimedata

# %%
sel = [crime.Category, 
           crime.Date,
           crime.DayOfWeek,
           crime.Description,
           crime.Latitude, 
           crime.Longitude,
           crime.PdDistrict,
           crime.month,
           crime.year,
           crime.Hour]
results = db.session.query(*sel).all()

# %%
crime =[]

# %%
for result in results:
        crimedata = {}
        crimedata["Category"] = result[0]
        crimedata["IncidentDate"] = result[1]
        crimedata["IncidentDayofWeek"] = result[2]
        crimedata["IncidentDescription"] = result[3]
        crimedata["Latitude"] = result[4]
        crimedata["Longtitude"] = result[5]
        crimedata["PoliceDistrict"] = result[6]
        crimedata["month"] = result[7]
        crimedata["year"] = result[8]
        crimedata["Hour"] = result[9]

        crime.append(crimedata)

# %%
crime
# Out:
# [{'Category': 'Larceny Theft',
#   'IncidentDate': '5/14/18',
#   'IncidentDayofWeek': 'Monday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.77186362,
#   'Longtitude': -122.4140273,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 21},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/14/18',
#   'IncidentDayofWeek': 'Monday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78284916,
#   'Longtitude': -122.4665655,
#   'PoliceDistrict': 'Richmond',
#   'month': 5,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/14/18',
#   'IncidentDayofWeek': 'Monday',
#   'IncidentDescription': 'PETTY THEFT FROM A BUILDING',
#   'Latitude': 37.77827178,
#   'Longtitude': -122.4074342,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 17},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/14/18',
#   'IncidentDayofWeek': 'Monday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78255435,
#   'Longtitude': -122.3973888,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 17},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/14/18',
#   'IncidentDayofWeek': 'Monday',
#   'IncidentDescription': 'GRAND THEFT SHOPLIFTING',
#   'Latitude': 37.78520719,
#   'Longtitude': -122.4066906,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 12},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/14/18',
#   'IncidentDayofWeek': 'Monday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.80157412,
#   'Longtitude': -122.4457381,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 12},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/14/18',
#   'IncidentDayofWeek': 'Monday',
#   'IncidentDescription': 'GRAND THEFT FROM PERSON',
#   'Latitude': 37.7821373,
#   'Longtitude': -122.415533,
#   'PoliceDistrict': 'Tenderloin',
#   'month': 5,
#   'year': 2018,
#   'Hour': 10},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/14/18',
#   'IncidentDayofWeek': 'Monday',
#   'IncidentDescription': 'PETTY THEFT SHOPLIFTING',
#   'Latitude': 37.78597748,
#   'Longtitude': -122.4053594,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 8},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/13/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM PERSON',
#   'Latitude': 37.75285342,
#   'Longtitude': -122.4081924,
#   'PoliceDistrict': 'Mission',
#   'month': 5,
#   'year': 2018,
#   'Hour': 23},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/13/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78284198,
#   'Longtitude': -122.4216671,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 22},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/13/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78743783,
#   'Longtitude': -122.419203,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 21},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/13/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'PETTY THEFT FROM UNLOCKED AUTO',
#   'Latitude': 37.76698711,
#   'Longtitude': -122.4278572,
#   'PoliceDistrict': 'Mission',
#   'month': 5,
#   'year': 2018,
#   'Hour': 20},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/13/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM A BUILDING',
#   'Latitude': 37.77310241,
#   'Longtitude': -122.4339491,
#   'PoliceDistrict': 'Park',
#   'month': 5,
#   'year': 2018,
#   'Hour': 17},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/13/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.77416582,
#   'Longtitude': -122.4594869,
#   'PoliceDistrict': 'Richmond',
#   'month': 5,
#   'year': 2018,
#   'Hour': 17},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/13/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'PETTY THEFT SHOPLIFTING',
#   'Latitude': 37.78673422,
#   'Longtitude': -122.4058954,
#   'PoliceDistrict': 'Tenderloin',
#   'month': 5,
#   'year': 2018,
#   'Hour': 16},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/13/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT SHOPLIFTING',
#   'Latitude': 37.72693464,
#   'Longtitude': -122.4779767,
#   'PoliceDistrict': 'Taraval',
#   'month': 5,
#   'year': 2018,
#   'Hour': 16},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/13/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'PETTY THEFT SHOPLIFTING',
#   'Latitude': 37.78506294,
#   'Longtitude': -122.406521,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 15},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/13/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT SHOPLIFTING',
#   'Latitude': 37.7884486,
#   'Longtitude': -122.4076129,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 15},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/13/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.79915966,
#   'Longtitude': -122.4342278,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 14},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/13/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.7702082,
#   'Longtitude': -122.4453468,
#   'PoliceDistrict': 'Park',
#   'month': 5,
#   'year': 2018,
#   'Hour': 14},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/13/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM A BUILDING',
#   'Latitude': 37.79908807,
#   'Longtitude': -122.40515,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 13},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/13/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'PETTY THEFT SHOPLIFTING',
#   'Latitude': 37.79411691,
#   'Longtitude': -122.3965564,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 13},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/13/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'PETTY THEFT SHOPLIFTING',
#   'Latitude': 37.78418935,
#   'Longtitude': -122.4076335,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 13},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/13/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78832797,
#   'Longtitude': -122.3888884,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 12},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/13/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.80493754,
#   'Longtitude': -122.4042308,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 10},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/13/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'LOST PROPERTY, PETTY THEFT',
#   'Latitude': 37.78526863,
#   'Longtitude': -122.40307,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 9},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/13/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.72535427,
#   'Longtitude': -122.3873691,
#   'PoliceDistrict': 'Bayview',
#   'month': 5,
#   'year': 2018,
#   'Hour': 4},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/13/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.7850961,
#   'Longtitude': -122.4127588,
#   'PoliceDistrict': 'Tenderloin',
#   'month': 5,
#   'year': 2018,
#   'Hour': 2},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/13/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT OF PROPERTY',
#   'Latitude': 37.78672593,
#   'Longtitude': -122.4127553,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 0},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/13/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM PERSON',
#   'Latitude': 37.79924013,
#   'Longtitude': -122.407371,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 0},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78378482,
#   'Longtitude': -122.3989327,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 23},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'GRAND THEFT FROM A BUILDING',
#   'Latitude': 37.79620622,
#   'Longtitude': -122.4344847,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 22},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.80622143,
#   'Longtitude': -122.4238488,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 21},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'GRAND THEFT FROM PERSON',
#   'Latitude': 37.78351007,
#   'Longtitude': -122.4053955,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 20},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78486569,
#   'Longtitude': -122.4127841,
#   'PoliceDistrict': 'Tenderloin',
#   'month': 5,
#   'year': 2018,
#   'Hour': 20},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'PETTY THEFT SHOPLIFTING',
#   'Latitude': 37.78063128,
#   'Longtitude': -122.4756465,
#   'PoliceDistrict': 'Richmond',
#   'month': 5,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'GRAND THEFT FROM PERSON',
#   'Latitude': 37.78999516,
#   'Longtitude': -122.4025356,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.74105755,
#   'Longtitude': -122.40648,
#   'PoliceDistrict': 'Bayview',
#   'month': 5,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'GRAND THEFT FROM UNLOCKED AUTO',
#   'Latitude': 37.74024022,
#   'Longtitude': -122.3852844,
#   'PoliceDistrict': 'Bayview',
#   'month': 5,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.80456518,
#   'Longtitude': -122.4218187,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78211726,
#   'Longtitude': -122.4198425,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'GRAND THEFT SHOPLIFTING',
#   'Latitude': 37.78418935,
#   'Longtitude': -122.4076335,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 18},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'PETTY THEFT SHOPLIFTING',
#   'Latitude': 37.78356994,
#   'Longtitude': -122.4084211,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 17},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.77730095,
#   'Longtitude': -122.4196977,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 17},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'GRAND THEFT PICKPOCKET',
#   'Latitude': 37.78399168,
#   'Longtitude': -122.4080683,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 17},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'PETTY THEFT SHOPLIFTING',
#   'Latitude': 37.78418935,
#   'Longtitude': -122.4076335,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 16},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.77113324,
#   'Longtitude': -122.4575076,
#   'PoliceDistrict': 'Park',
#   'month': 5,
#   'year': 2018,
#   'Hour': 15},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78883791,
#   'Longtitude': -122.3894326,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 15},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.77837934,
#   'Longtitude': -122.4451847,
#   'PoliceDistrict': 'Park',
#   'month': 5,
#   'year': 2018,
#   'Hour': 15},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'GRAND THEFT SHOPLIFTING',
#   'Latitude': 37.7884486,
#   'Longtitude': -122.4076129,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 14},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.76349544,
#   'Longtitude': -122.4184863,
#   'PoliceDistrict': 'Mission',
#   'month': 5,
#   'year': 2018,
#   'Hour': 14},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'GRAND THEFT FROM PERSON',
#   'Latitude': 37.78651941,
#   'Longtitude': -122.41481,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 13},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'GRAND THEFT FROM UNLOCKED AUTO',
#   'Latitude': 37.72977741,
#   'Longtitude': -122.4055904,
#   'PoliceDistrict': 'Bayview',
#   'month': 5,
#   'year': 2018,
#   'Hour': 13},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'PETTY THEFT OF PROPERTY',
#   'Latitude': 37.74840057,
#   'Longtitude': -122.4224156,
#   'PoliceDistrict': 'Mission',
#   'month': 5,
#   'year': 2018,
#   'Hour': 13},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'GRAND THEFT PICKPOCKET',
#   'Latitude': 37.78331041,
#   'Longtitude': -122.3883799,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 12},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.73161977,
#   'Longtitude': -122.4321119,
#   'PoliceDistrict': 'Ingleside',
#   'month': 5,
#   'year': 2018,
#   'Hour': 12},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'PETTY THEFT SHOPLIFTING',
#   'Latitude': 37.78596801,
#   'Longtitude': -122.4078778,
#   'PoliceDistrict': 'Tenderloin',
#   'month': 5,
#   'year': 2018,
#   'Hour': 11},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'PETTY THEFT SHOPLIFTING',
#   'Latitude': 37.78404739,
#   'Longtitude': -122.4337013,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 10},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'PETTY THEFT FROM UNLOCKED AUTO',
#   'Latitude': 37.78408887,
#   'Longtitude': -122.401561,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 10},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'GRAND THEFT FROM A BUILDING',
#   'Latitude': 37.77069679,
#   'Longtitude': -122.4077021,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 10},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'PETTY THEFT OF PROPERTY',
#   'Latitude': 37.78415049,
#   'Longtitude': -122.4345637,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 10},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'PETTY THEFT FROM A BUILDING',
#   'Latitude': 37.75633027,
#   'Longtitude': -122.3955654,
#   'PoliceDistrict': 'Bayview',
#   'month': 5,
#   'year': 2018,
#   'Hour': 3},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'GRAND THEFT FROM PERSON',
#   'Latitude': 37.78321452,
#   'Longtitude': -122.4107688,
#   'PoliceDistrict': 'Tenderloin',
#   'month': 5,
#   'year': 2018,
#   'Hour': 2},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/12/18',
#   'IncidentDayofWeek': 'Saturday',
#   'IncidentDescription': 'PETTY THEFT FROM A BUILDING',
#   'Latitude': 37.75507596,
#   'Longtitude': -122.4111259,
#   'PoliceDistrict': 'Mission',
#   'month': 5,
#   'year': 2018,
#   'Hour': 1},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.77081941,
#   'Longtitude': -122.4091384,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 23},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.74110929,
#   'Longtitude': -122.3884784,
#   'PoliceDistrict': 'Bayview',
#   'month': 5,
#   'year': 2018,
#   'Hour': 23},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.79284128,
#   'Longtitude': -122.4245198,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 23},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78864422,
#   'Longtitude': -122.4169922,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 23},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.7775531,
#   'Longtitude': -122.409924,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 23},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'PETTY THEFT OF PROPERTY',
#   'Latitude': 37.75982792,
#   'Longtitude': -122.4259205,
#   'PoliceDistrict': 'Mission',
#   'month': 5,
#   'year': 2018,
#   'Hour': 22},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'ATTEMPTED THEFT FROM LOCKED VEHICLE',
#   'Latitude': 37.71075458,
#   'Longtitude': -122.4323476,
#   'PoliceDistrict': 'Ingleside',
#   'month': 5,
#   'year': 2018,
#   'Hour': 22},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.77883482,
#   'Longtitude': -122.395986,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 21},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.76337581,
#   'Longtitude': -122.4204347,
#   'PoliceDistrict': 'Mission',
#   'month': 5,
#   'year': 2018,
#   'Hour': 20},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'PETTY THEFT FROM UNLOCKED AUTO',
#   'Latitude': 37.74270308,
#   'Longtitude': -122.3879274,
#   'PoliceDistrict': 'Bayview',
#   'month': 5,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.7831499,
#   'Longtitude': -122.4183602,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 18},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.77619162,
#   'Longtitude': -122.4227669,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 18},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'PETTY THEFT FROM UNLOCKED AUTO',
#   'Latitude': 37.72469164,
#   'Longtitude': -122.4563612,
#   'PoliceDistrict': 'Ingleside',
#   'month': 5,
#   'year': 2018,
#   'Hour': 17},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.800781,
#   'Longtitude': -122.398862,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 15},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'PETTY THEFT SHOPLIFTING',
#   'Latitude': 37.78356994,
#   'Longtitude': -122.4084211,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 14},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'GRAND THEFT FROM PERSON',
#   'Latitude': 37.78475366,
#   'Longtitude': -122.4211952,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 14},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'ATTEMPTED THEFT FROM LOCKED VEHICLE',
#   'Latitude': 37.78780636,
#   'Longtitude': -122.4234998,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 13},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'GRAND THEFT FROM A BUILDING',
#   'Latitude': 37.78331041,
#   'Longtitude': -122.3883799,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 13},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'GRAND THEFT SHOPLIFTING',
#   'Latitude': 37.78506294,
#   'Longtitude': -122.406521,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 12},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'GRAND THEFT FROM PERSON',
#   'Latitude': 37.77542071,
#   'Longtitude': -122.4034048,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 12},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'GRAND THEFT SHOPLIFTING',
#   'Latitude': 37.7884486,
#   'Longtitude': -122.4076129,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 11},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78302957,
#   'Longtitude': -122.4310464,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 11},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78544219,
#   'Longtitude': -122.4214831,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 11},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'PETTY THEFT FROM A BUILDING',
#   'Latitude': 37.78992,
#   'Longtitude': -122.4220627,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 10},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.77005279,
#   'Longtitude': -122.4130497,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 10},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'GRAND THEFT FROM A BUILDING',
#   'Latitude': 37.78553558,
#   'Longtitude': -122.4113028,
#   'PoliceDistrict': 'Tenderloin',
#   'month': 5,
#   'year': 2018,
#   'Hour': 9},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'PETTY THEFT SHOPLIFTING',
#   'Latitude': 37.76349824,
#   'Longtitude': -122.4798158,
#   'PoliceDistrict': 'Taraval',
#   'month': 5,
#   'year': 2018,
#   'Hour': 9},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'PETTY THEFT OF PROPERTY',
#   'Latitude': 37.79195104,
#   'Longtitude': -122.3932283,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 5},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'GRAND THEFT OF PROPERTY',
#   'Latitude': 37.79005279,
#   'Longtitude': -122.4001948,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 3},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'GRAND THEFT FROM PERSON',
#   'Latitude': 37.760433,
#   'Longtitude': -122.4159298,
#   'PoliceDistrict': 'Mission',
#   'month': 5,
#   'year': 2018,
#   'Hour': 2},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'LOST PROPERTY, PETTY THEFT',
#   'Latitude': 37.75888272,
#   'Longtitude': -122.4291632,
#   'PoliceDistrict': 'Mission',
#   'month': 5,
#   'year': 2018,
#   'Hour': 1},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'PETTY THEFT FROM UNLOCKED AUTO',
#   'Latitude': 37.78479944,
#   'Longtitude': -122.485009,
#   'PoliceDistrict': 'Richmond',
#   'month': 5,
#   'year': 2018,
#   'Hour': 1},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/11/18',
#   'IncidentDayofWeek': 'Friday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78766372,
#   'Longtitude': -122.4133581,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 0},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78302957,
#   'Longtitude': -122.4310464,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 23},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'PETTY THEFT FROM UNLOCKED AUTO',
#   'Latitude': 37.75413852,
#   'Longtitude': -122.4446701,
#   'PoliceDistrict': 'Park',
#   'month': 5,
#   'year': 2018,
#   'Hour': 23},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.80549603,
#   'Longtitude': -122.422009,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 21},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.80627287,
#   'Longtitude': -122.4230251,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 21},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.77542071,
#   'Longtitude': -122.4034048,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 20},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'ATTEMPTED THEFT FROM LOCKED VEHICLE',
#   'Latitude': 37.77542071,
#   'Longtitude': -122.4034048,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 20},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'GRAND THEFT FROM PERSON',
#   'Latitude': 37.76814038,
#   'Longtitude': -122.4222016,
#   'PoliceDistrict': 'Mission',
#   'month': 5,
#   'year': 2018,
#   'Hour': 20},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'PETTY THEFT SHOPLIFTING',
#   'Latitude': 37.73394977,
#   'Longtitude': -122.489714,
#   'PoliceDistrict': 'Taraval',
#   'month': 5,
#   'year': 2018,
#   'Hour': 20},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'GRAND THEFT SHOPLIFTING',
#   'Latitude': 37.74222798,
#   'Longtitude': -122.4221419,
#   'PoliceDistrict': 'Ingleside',
#   'month': 5,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'ATTEMPTED THEFT FROM LOCKED VEHICLE',
#   'Latitude': 37.76976955,
#   'Longtitude': -122.4072576,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.76422056,
#   'Longtitude': -122.4196583,
#   'PoliceDistrict': 'Mission',
#   'month': 5,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'GRAND THEFT OF PROPERTY',
#   'Latitude': 37.80572044,
#   'Longtitude': -122.4203737,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.77619641,
#   'Longtitude': -122.4396838,
#   'PoliceDistrict': 'Park',
#   'month': 5,
#   'year': 2018,
#   'Hour': 18},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.77958458,
#   'Longtitude': -122.41677,
#   'PoliceDistrict': 'Tenderloin',
#   'month': 5,
#   'year': 2018,
#   'Hour': 18},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'PETTY THEFT SHOPLIFTING',
#   'Latitude': 37.78232359,
#   'Longtitude': -122.4037933,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 17},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'PETTY THEFT FROM A BUILDING',
#   'Latitude': 37.79713728,
#   'Longtitude': -122.4346731,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 16},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'GRAND THEFT PICKPOCKET',
#   'Latitude': 37.78651941,
#   'Longtitude': -122.41481,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 16},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'THEFT FROM MERCHANT OR LIBRARY',
#   'Latitude': 37.72425605,
#   'Longtitude': -122.4350413,
#   'PoliceDistrict': 'Ingleside',
#   'month': 5,
#   'year': 2018,
#   'Hour': 16},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'PETTY THEFT SHOPLIFTING',
#   'Latitude': 37.78690218,
#   'Longtitude': -122.408065,
#   'PoliceDistrict': 'Tenderloin',
#   'month': 5,
#   'year': 2018,
#   'Hour': 16},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'PETTY THEFT FROM A BUILDING',
#   'Latitude': 37.78630722,
#   'Longtitude': -122.4052948,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 15},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'PETTY THEFT SHOPLIFTING',
#   'Latitude': 37.78418935,
#   'Longtitude': -122.4076335,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 15},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'PETTY THEFT FROM A BUILDING',
#   'Latitude': 37.77069679,
#   'Longtitude': -122.4077021,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 14},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'THEFT OF COMPUTERS OR CELL PHONES',
#   'Latitude': 37.75250508,
#   'Longtitude': -122.414089,
#   'PoliceDistrict': 'Mission',
#   'month': 5,
#   'year': 2018,
#   'Hour': 14},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.75250508,
#   'Longtitude': -122.414089,
#   'PoliceDistrict': 'Mission',
#   'month': 5,
#   'year': 2018,
#   'Hour': 14},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'GRAND THEFT OF PROPERTY',
#   'Latitude': 37.78982842,
#   'Longtitude': -122.4038466,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 14},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.7590298,
#   'Longtitude': -122.4258444,
#   'PoliceDistrict': 'Mission',
#   'month': 5,
#   'year': 2018,
#   'Hour': 14},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.80199424,
#   'Longtitude': -122.4196161,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 13},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.80199424,
#   'Longtitude': -122.4196161,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 13},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.8025736,
#   'Longtitude': -122.4003875,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 12},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'PETTY THEFT FROM A BUILDING',
#   'Latitude': 37.79484181,
#   'Longtitude': -122.4308384,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 12},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'PETTY THEFT SHOPLIFTING',
#   'Latitude': 37.78506294,
#   'Longtitude': -122.406521,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 12},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'GRAND THEFT PICKPOCKET',
#   'Latitude': 37.77542071,
#   'Longtitude': -122.4034048,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 12},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'PETTY THEFT OF PROPERTY',
#   'Latitude': 37.76586724,
#   'Longtitude': -122.4310287,
#   'PoliceDistrict': 'Mission',
#   'month': 5,
#   'year': 2018,
#   'Hour': 11},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78566804,
#   'Longtitude': -122.5003761,
#   'PoliceDistrict': 'Richmond',
#   'month': 5,
#   'year': 2018,
#   'Hour': 11},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'GRAND THEFT PICKPOCKET',
#   'Latitude': 37.77829352,
#   'Longtitude': -122.4154488,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 9},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'GRAND THEFT FROM A BUILDING',
#   'Latitude': 37.75773634,
#   'Longtitude': -122.4630828,
#   'PoliceDistrict': 'Park',
#   'month': 5,
#   'year': 2018,
#   'Hour': 8},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.76125771,
#   'Longtitude': -122.4283554,
#   'PoliceDistrict': 'Mission',
#   'month': 5,
#   'year': 2018,
#   'Hour': 8},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.7334145,
#   'Longtitude': -122.4809914,
#   'PoliceDistrict': 'Taraval',
#   'month': 5,
#   'year': 2018,
#   'Hour': 6},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'THEFT OF COMPUTERS OR CELL PHONES',
#   'Latitude': 37.74396011,
#   'Longtitude': -122.42899,
#   'PoliceDistrict': 'Ingleside',
#   'month': 5,
#   'year': 2018,
#   'Hour': 6},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'PETTY THEFT FROM A BUILDING',
#   'Latitude': 37.79198058,
#   'Longtitude': -122.3977422,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 6},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.76140689,
#   'Longtitude': -122.4052264,
#   'PoliceDistrict': 'Bayview',
#   'month': 5,
#   'year': 2018,
#   'Hour': 4},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'PETTY THEFT BICYCLE',
#   'Latitude': 37.76329969,
#   'Longtitude': -122.4217338,
#   'PoliceDistrict': 'Mission',
#   'month': 5,
#   'year': 2018,
#   'Hour': 2},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/10/18',
#   'IncidentDayofWeek': 'Thursday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.77562497,
#   'Longtitude': -122.4328328,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 1},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.72720494,
#   'Longtitude': -122.4105462,
#   'PoliceDistrict': 'Bayview',
#   'month': 5,
#   'year': 2018,
#   'Hour': 23},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.76267028,
#   'Longtitude': -122.4351877,
#   'PoliceDistrict': 'Park',
#   'month': 5,
#   'year': 2018,
#   'Hour': 22},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.80582429,
#   'Longtitude': -122.4119531,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 22},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78057979,
#   'Longtitude': -122.476719,
#   'PoliceDistrict': 'Richmond',
#   'month': 5,
#   'year': 2018,
#   'Hour': 21},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'GRAND THEFT FROM PERSON',
#   'Latitude': 37.79690855,
#   'Longtitude': -122.4052917,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 21},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'GRAND THEFT FROM UNLOCKED AUTO',
#   'Latitude': 37.77542071,
#   'Longtitude': -122.4034048,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 21},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'PETTY THEFT SHOPLIFTING',
#   'Latitude': 37.78782711,
#   'Longtitude': -122.4083843,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 20},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78267772,
#   'Longtitude': -122.4444413,
#   'PoliceDistrict': 'Park',
#   'month': 5,
#   'year': 2018,
#   'Hour': 20},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78514992,
#   'Longtitude': -122.4330842,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 20},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.80040249,
#   'Longtitude': -122.4395049,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 20},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.79604395,
#   'Longtitude': -122.4060462,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 20},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'GRAND THEFT FROM PERSON',
#   'Latitude': 37.80081266,
#   'Longtitude': -122.4362753,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 20},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.77712149,
#   'Longtitude': -122.4136811,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.79321819,
#   'Longtitude': -122.4069688,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.76924706,
#   'Longtitude': -122.4269556,
#   'PoliceDistrict': 'Mission',
#   'month': 5,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'GRAND THEFT PICKPOCKET',
#   'Latitude': 37.76006971,
#   'Longtitude': -122.4349948,
#   'PoliceDistrict': 'Mission',
#   'month': 5,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'GRAND THEFT FROM A BUILDING',
#   'Latitude': 37.80649569,
#   'Longtitude': -122.4104744,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78038213,
#   'Longtitude': -122.4810033,
#   'PoliceDistrict': 'Richmond',
#   'month': 5,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.76924706,
#   'Longtitude': -122.4269556,
#   'PoliceDistrict': 'Mission',
#   'month': 5,
#   'year': 2018,
#   'Hour': 18},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'PETTY THEFT SHOPLIFTING',
#   'Latitude': 37.76571844,
#   'Longtitude': -122.4095299,
#   'PoliceDistrict': 'Mission',
#   'month': 5,
#   'year': 2018,
#   'Hour': 18},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'PETTY THEFT FROM A BUILDING',
#   'Latitude': 37.78690887,
#   'Longtitude': -122.4225406,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 18},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'GRAND THEFT FROM A BUILDING',
#   'Latitude': 37.76505012,
#   'Longtitude': -122.4196718,
#   'PoliceDistrict': 'Mission',
#   'month': 5,
#   'year': 2018,
#   'Hour': 18},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.79846697,
#   'Longtitude': -122.409213,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 18},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.80554096,
#   'Longtitude': -122.4061461,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 17},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.75408299,
#   'Longtitude': -122.4275889,
#   'PoliceDistrict': 'Mission',
#   'month': 5,
#   'year': 2018,
#   'Hour': 17},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'GRAND THEFT FROM PERSON',
#   'Latitude': 37.788817,
#   'Longtitude': -122.4008163,
#   'PoliceDistrict': 'Southern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 17},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'PETTY THEFT SHOPLIFTING',
#   'Latitude': 37.78842878,
#   'Longtitude': -122.4338136,
#   'PoliceDistrict': 'Northern',
#   'month': 5,
#   'year': 2018,
#   'Hour': 17},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.73487268,
#   'Longtitude': -122.4805114,
#   'PoliceDistrict': 'Taraval',
#   'month': 5,
#   'year': 2018,
#   'Hour': 17},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'PETTY THEFT OF PROPERTY',
#   'Latitude': 37.7882399,
#   'Longtitude': -122.4092561,
#   'PoliceDistrict': 'Central',
#   'month': 5,
#   'year': 2018,
#   'Hour': 16},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '5/9/18',
#   'IncidentDayofWeek': 'Wednesday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.70864736,
#   'Longtitude': -122.4053857,
# ...
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.7823799,
#   'Longtitude': -122.4173405,
#   'PoliceDistrict': 'Northern',
#   'month': 4,
#   'year': 2018,
#   'Hour': 0},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/30/18',
#   'IncidentDayofWeek': 'Monday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.79251071,
#   'Longtitude': -122.4413342,
#   'PoliceDistrict': 'Richmond',
#   'month': 4,
#   'year': 2018,
#   'Hour': 0},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/30/18',
#   'IncidentDayofWeek': 'Monday',
#   'IncidentDescription': 'GRAND THEFT OF PROPERTY',
#   'Latitude': 37.79393382,
#   'Longtitude': -122.4230493,
#   'PoliceDistrict': 'Northern',
#   'month': 4,
#   'year': 2018,
#   'Hour': 0},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.74157677,
#   'Longtitude': -122.4874792,
#   'PoliceDistrict': 'Taraval',
#   'month': 4,
#   'year': 2018,
#   'Hour': 23},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.74224185,
#   'Longtitude': -122.4250512,
#   'PoliceDistrict': 'Ingleside',
#   'month': 4,
#   'year': 2018,
#   'Hour': 23},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.79850835,
#   'Longtitude': -122.4097917,
#   'PoliceDistrict': 'Central',
#   'month': 4,
#   'year': 2018,
#   'Hour': 22},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.76275495,
#   'Longtitude': -122.3936133,
#   'PoliceDistrict': 'Bayview',
#   'month': 4,
#   'year': 2018,
#   'Hour': 22},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'ATTEMPTED THEFT FROM A BUILDING',
#   'Latitude': 37.7809167,
#   'Longtitude': -122.4539427,
#   'PoliceDistrict': 'Richmond',
#   'month': 4,
#   'year': 2018,
#   'Hour': 21},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM UNLOCKED AUTO',
#   'Latitude': 37.80768876,
#   'Longtitude': -122.4123335,
#   'PoliceDistrict': 'Central',
#   'month': 4,
#   'year': 2018,
#   'Hour': 21},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'PETTY THEFT OF PROPERTY',
#   'Latitude': 37.78202385,
#   'Longtitude': -122.4011616,
#   'PoliceDistrict': 'Southern',
#   'month': 4,
#   'year': 2018,
#   'Hour': 21},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78467692,
#   'Longtitude': -122.4321176,
#   'PoliceDistrict': 'Northern',
#   'month': 4,
#   'year': 2018,
#   'Hour': 20},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78604277,
#   'Longtitude': -122.4265297,
#   'PoliceDistrict': 'Northern',
#   'month': 4,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.7763701,
#   'Longtitude': -122.4195075,
#   'PoliceDistrict': 'Northern',
#   'month': 4,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78351007,
#   'Longtitude': -122.4053955,
#   'PoliceDistrict': 'Southern',
#   'month': 4,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.76656903,
#   'Longtitude': -122.4215346,
#   'PoliceDistrict': 'Mission',
#   'month': 4,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.72116508,
#   'Longtitude': -122.4374615,
#   'PoliceDistrict': 'Ingleside',
#   'month': 4,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT OF PROPERTY',
#   'Latitude': 37.78244926,
#   'Longtitude': -122.4392991,
#   'PoliceDistrict': 'Park',
#   'month': 4,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'PETTY THEFT OF PROPERTY',
#   'Latitude': 37.76557967,
#   'Longtitude': -122.452122,
#   'PoliceDistrict': 'Park',
#   'month': 4,
#   'year': 2018,
#   'Hour': 19},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.77254054,
#   'Longtitude': -122.4662047,
#   'PoliceDistrict': 'Richmond',
#   'month': 4,
#   'year': 2018,
#   'Hour': 18},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.79251827,
#   'Longtitude': -122.3910043,
#   'PoliceDistrict': 'Southern',
#   'month': 4,
#   'year': 2018,
#   'Hour': 18},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.77778137,
#   'Longtitude': -122.4215417,
#   'PoliceDistrict': 'Northern',
#   'month': 4,
#   'year': 2018,
#   'Hour': 18},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT OF PROPERTY',
#   'Latitude': 37.77931171,
#   'Longtitude': -122.3978496,
#   'PoliceDistrict': 'Southern',
#   'month': 4,
#   'year': 2018,
#   'Hour': 18},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.77542071,
#   'Longtitude': -122.4034048,
#   'PoliceDistrict': 'Southern',
#   'month': 4,
#   'year': 2018,
#   'Hour': 18},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.7899181,
#   'Longtitude': -122.4069776,
#   'PoliceDistrict': 'Central',
#   'month': 4,
#   'year': 2018,
#   'Hour': 18},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.76624632,
#   'Longtitude': -122.4104781,
#   'PoliceDistrict': 'Mission',
#   'month': 4,
#   'year': 2018,
#   'Hour': 18},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'PETTY THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78013295,
#   'Longtitude': -122.4863597,
#   'PoliceDistrict': 'Richmond',
#   'month': 4,
#   'year': 2018,
#   'Hour': 17},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'PETTY THEFT OF PROPERTY',
#   'Latitude': 37.78475366,
#   'Longtitude': -122.4211952,
#   'PoliceDistrict': 'Northern',
#   'month': 4,
#   'year': 2018,
#   'Hour': 17},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78702327,
#   'Longtitude': -122.4030305,
#   'PoliceDistrict': 'Southern',
#   'month': 4,
#   'year': 2018,
#   'Hour': 17},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM UNLOCKED AUTO',
#   'Latitude': 37.77254054,
#   'Longtitude': -122.4662047,
#   'PoliceDistrict': 'Richmond',
#   'month': 4,
#   'year': 2018,
#   'Hour': 17},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'PETTY THEFT OF PROPERTY',
#   'Latitude': 37.76196742,
#   'Longtitude': -122.4171804,
#   'PoliceDistrict': 'Mission',
#   'month': 4,
#   'year': 2018,
#   'Hour': 16},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM UNLOCKED AUTO',
#   'Latitude': 37.77802113,
#   'Longtitude': -122.4215229,
#   'PoliceDistrict': 'Northern',
#   'month': 4,
#   'year': 2018,
#   'Hour': 16},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.76125771,
#   'Longtitude': -122.4283554,
#   'PoliceDistrict': 'Mission',
#   'month': 4,
#   'year': 2018,
#   'Hour': 16},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM PERSON',
#   'Latitude': 37.7933285,
#   'Longtitude': -122.4069761,
#   'PoliceDistrict': 'Central',
#   'month': 4,
#   'year': 2018,
#   'Hour': 16},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.76779239,
#   'Longtitude': -122.4278675,
#   'PoliceDistrict': 'Mission',
#   'month': 4,
#   'year': 2018,
#   'Hour': 16},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.76050007,
#   'Longtitude': -122.4148451,
#   'PoliceDistrict': 'Mission',
#   'month': 4,
#   'year': 2018,
#   'Hour': 16},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.80634189,
#   'Longtitude': -122.4154355,
#   'PoliceDistrict': 'Central',
#   'month': 4,
#   'year': 2018,
#   'Hour': 16},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT OF PROPERTY',
#   'Latitude': 37.77622099,
#   'Longtitude': -122.4116098,
#   'PoliceDistrict': 'Southern',
#   'month': 4,
#   'year': 2018,
#   'Hour': 16},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'PETTY THEFT OF PROPERTY',
#   'Latitude': 37.78331041,
#   'Longtitude': -122.3883799,
#   'PoliceDistrict': 'Southern',
#   'month': 4,
#   'year': 2018,
#   'Hour': 16},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'PETTY THEFT OF PROPERTY',
#   'Latitude': 37.76422056,
#   'Longtitude': -122.4196583,
#   'PoliceDistrict': 'Mission',
#   'month': 4,
#   'year': 2018,
#   'Hour': 15},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.74904131,
#   'Longtitude': -122.4181373,
#   'PoliceDistrict': 'Mission',
#   'month': 4,
#   'year': 2018,
#   'Hour': 14},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'PETTY THEFT OF PROPERTY',
#   'Latitude': 37.80287457,
#   'Longtitude': -122.4122164,
#   'PoliceDistrict': 'Central',
#   'month': 4,
#   'year': 2018,
#   'Hour': 14},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78397572,
#   'Longtitude': -122.3925455,
#   'PoliceDistrict': 'Southern',
#   'month': 4,
#   'year': 2018,
#   'Hour': 14},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.76437256,
#   'Longtitude': -122.4308826,
#   'PoliceDistrict': 'Mission',
#   'month': 4,
#   'year': 2018,
#   'Hour': 14},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.76208597,
#   'Longtitude': -122.4284357,
#   'PoliceDistrict': 'Mission',
#   'month': 4,
#   'year': 2018,
#   'Hour': 14},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.80427189,
#   'Longtitude': -122.4482784,
#   'PoliceDistrict': 'Northern',
#   'month': 4,
#   'year': 2018,
#   'Hour': 13},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.7800333,
#   'Longtitude': -122.4642799,
#   'PoliceDistrict': 'Richmond',
#   'month': 4,
#   'year': 2018,
#   'Hour': 13},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.76234449,
#   'Longtitude': -122.4238785,
#   'PoliceDistrict': 'Mission',
#   'month': 4,
#   'year': 2018,
#   'Hour': 13},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM UNLOCKED AUTO',
#   'Latitude': 37.77428685,
#   'Longtitude': -122.4875355,
#   'PoliceDistrict': 'Richmond',
#   'month': 4,
#   'year': 2018,
#   'Hour': 13},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'PETTY THEFT SHOPLIFTING',
#   'Latitude': 37.78798955,
#   'Longtitude': -122.4051548,
#   'PoliceDistrict': 'Central',
#   'month': 4,
#   'year': 2018,
#   'Hour': 12},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT OF PROPERTY',
#   'Latitude': 37.76176772,
#   'Longtitude': -122.4350121,
#   'PoliceDistrict': 'Mission',
#   'month': 4,
#   'year': 2018,
#   'Hour': 12},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.76988426,
#   'Longtitude': -122.4020758,
#   'PoliceDistrict': 'Southern',
#   'month': 4,
#   'year': 2018,
#   'Hour': 12},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.78768907,
#   'Longtitude': -122.436141,
#   'PoliceDistrict': 'Richmond',
#   'month': 4,
#   'year': 2018,
#   'Hour': 12},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.80150566,
#   'Longtitude': -122.4177715,
#   'PoliceDistrict': 'Central',
#   'month': 4,
#   'year': 2018,
#   'Hour': 11},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'GRAND THEFT FROM LOCKED AUTO',
#   'Latitude': 37.80175869,
#   'Longtitude': -122.4212614,
#   'PoliceDistrict': 'Central',
#   'month': 4,
#   'year': 2018,
#   'Hour': 11},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'LOST PROPERTY, PETTY THEFT',
#   'Latitude': 37.77689582,
#   'Longtitude': -122.4092025,
#   'PoliceDistrict': 'Southern',
#   'month': 4,
#   'year': 2018,
#   'Hour': 11},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'PETTY THEFT SHOPLIFTING',
#   'Latitude': 37.72852806,
#   'Longtitude': -122.4756475,
#   'PoliceDistrict': 'Taraval',
#   'month': 4,
#   'year': 2018,
#   'Hour': 11},
#  {'Category': 'Larceny Theft',
#   'IncidentDate': '4/29/18',
#   'IncidentDayofWeek': 'Sunday',
#   'IncidentDescription': 'LOST PROPERTY, PETTY THEFT',
#   'Latitude': 37.78306814,
#   'Longtitude': -122.4628289,
#   'PoliceDistrict': 'Richmond',
#   'month': 4,
#   'year': 2018,
#   'Hour': 11},
#  ...]
